# %% [markdown]
# # 展示如何使用npy_extract提取特征以及标签
#
# ⚠ **Notice**：
# * 在前置数据中已经进行了monomer的筛选，该文件读到的所有npy文件均是单体的信息
# * 阈值为SIF：270，SGF：250，异常值均为700
# *
#
#
# **函数位置**
#
# /src/feature_extraction/load_data.py
#
# **NPY数据位置**
#
# /src/npy_datas
#
# 读取的是已经提取成功的数据备份，重新执行phase1的代码不会影响

# %%
# -----------------------------环境配置-----------------------------
import sys
from pathlib import Path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))


#-----------------------------调用示例-----------------------------
# 在库中获取对应的方法
from feature_extraction import load_data
load_data_from_npy = load_data.load_data_from_npy
# 方法使用案例
result = load_data_from_npy(   
    dataset='US9624268',   # 数据集名称
    target='SIF',          # 任务类型 SIF or SGF
    exclude='None'         # 排除的分子指纹类型 Avalon, Morgan, None，All
)



#-----------------------------输出结果-----------------------------
# 返回内容result为字典
X_filtered= result['X']
y_filtered= result['y']
y_binary= result['y_binary']
feature_names= result['feature_names']


print("展示输出效果，以及输出结果的数据类型:")
print(X_filtered.shape,y_filtered.shape, y_binary.shape, len(feature_names))
print(type(X_filtered),type(y_filtered), type(y_binary), type(feature_names))
# Out:
# 展示输出效果，以及输出结果的数据类型:
# (130, 1560) (130,) (130,) 1560
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
